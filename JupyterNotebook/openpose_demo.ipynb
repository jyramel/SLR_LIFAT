# %%
import pyopenpose as op
import cv2
from matplotlib import pyplot as plt
import sys
import os
try:
    from myOpenpose import *
except:
    sys.path.append('/home/nmiguens/Python')
    from myOpenpose import *

# %%
imagePath = "/home/nmiguens/Datasets/test3.jpg"

# %%
imageToProcess = cv2.imread(imagePath)
plt.imshow(imageToProcess)
plt.title('my picture')
plt.show()

# %%
params = set_params(body = 1, hand = True, hand_detector = 0, nb_people_max = -1)
datum = opImage_display(imagePath, params)
